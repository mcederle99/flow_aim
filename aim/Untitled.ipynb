# %%
import numpy as np

# %%
ret = np.load('returns.npy')

# %%
print(len(ret))
# Out:
# 994

# %%
time = np.linspace(30000, 5000000, 994)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(time[3:], ret[3:])

plt.show()
