# %%
import numpy as np

# %%
ret = np.load('returns.npy')

# %%
time = np.linspace(30000, 30000+5000*994, 994)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(time, ret)

plt.show()

# %%
ret_more_up = np.load('returns_more_updates.npy')

# %%
time1 = np.linspace(30000, 30000+5000*199, 199)

# %%
plt.plot(time1, ret_more_up)

plt.show()

# %%
ret_2v = np.load('../new_aim/returns_new.npy')

# %%
time2 = np.linspace(30000, 30000+5000*95, 95)

# %%
plt.plot(time2, ret_2v)

plt.show()
